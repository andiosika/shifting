# %%
import pandas as pd

# %%
df = pd.read_csv('Trade-Register-1950-2019-suppliers copy.txt', delimiter='\t', encoding='utf-8' )

# %%
df.head()
# Out:
#         Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3         Year(s)  \
# 0              NaN        NaN         NaN        NaN     NaN     NaN
# 1              NaN        NaN         NaN        NaN     NaN     NaN
# 2          Albania        NaN         NaN        NaN     NaN     NaN
# 3  R: Burkina Faso       (12)  M-43 120mm     Mortar  (2011)    2011
# 4              NaN        NaN         NaN        NaN     NaN     NaN
#
#   Unnamed: 6             Supplier/ Unnamed: 8  No.  ...  No.   Unnamed: 15  \
# 0        NaN                   NaN        NaN  NaN  ...   NaN          NaN
# 1        NaN                   NaN        NaN  NaN  ...   NaN          NaN
# 2        NaN                   NaN        NaN  NaN  ...   NaN          NaN
# 3         12  Probably second-hand        NaN  NaN  ...   NaN          NaN
# 4        NaN                   NaN        NaN  NaN  ...   NaN          NaN
#
#    recipient (R)  ordered  designation  description  of order  delivery  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27035 entries, 0 to 27034
# Data columns (total 24 columns):
# Unnamed: 0       26898 non-null object
# Unnamed: 1       3317 non-null object
# Unnamed: 2       26649 non-null object
# Unnamed: 3       26762 non-null object
#                  26762 non-null object
# Year(s)          26685 non-null object
# Unnamed: 6       25998 non-null object
# Supplier/        25540 non-null object
# Unnamed: 8       18901 non-null object
# No.              0 non-null float64
# Weapon           0 non-null float64
# Weapon.1         0 non-null float64
# Year             0 non-null float64
# of               0 non-null float64
# No.              0 non-null float64
# Unnamed: 15      0 non-null float64
# recipient (R)    0 non-null float64
# ordered          0 non-null float64
# designation      0 non-null float64
# description      0 non-null float64
# of order         0 non-null float64
# delivery         0 non-null float64
# ...

# %%
df.drop(['No.', 'Weapon', 'Weapon.1', 'Year', 'of', 'No.', 'Unnamed: 15', 'recipient (R)', 'ordered',
         'designation', 'description', 'of order', 'delivery', 'delivered', 'Comments'],axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27035 entries, 0 to 27034
# Data columns (total 10 columns):
# Unnamed: 0    26898 non-null object
# Unnamed: 1    3317 non-null object
# Unnamed: 2    26649 non-null object
# Unnamed: 3    26762 non-null object
#               26762 non-null object
# Year(s)       26685 non-null object
# Unnamed: 6    25998 non-null object
# Supplier/     25540 non-null object
# Unnamed: 8    18901 non-null object
# No.           0 non-null float64
# dtypes: float64(1), object(9)
# memory usage: 2.1+ MB

# %%
df.drop(df.columns[len(df.columns)-1], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27035 entries, 0 to 27034
# Data columns (total 9 columns):
# Unnamed: 0    26898 non-null object
# Unnamed: 1    3317 non-null object
# Unnamed: 2    26649 non-null object
# Unnamed: 3    26762 non-null object
#               26762 non-null object
# Year(s)       26685 non-null object
# Unnamed: 6    25998 non-null object
# Supplier/     25540 non-null object
# Unnamed: 8    18901 non-null object
# dtypes: object(9)
# memory usage: 1.9+ MB

# %%
df.head(20)
# Out:
#              Unnamed: 0 Unnamed: 1          Unnamed: 2          Unnamed: 3  \
# 0                   NaN        NaN                 NaN                 NaN
# 1                   NaN        NaN                 NaN                 NaN
# 2               Albania        NaN                 NaN                 NaN
# 3       R: Burkina Faso       (12)          M-43 120mm              Mortar
# 4                   NaN        NaN                 NaN                 NaN
# 5               Algeria        NaN                 NaN                 NaN
# 6             R: Angola          4       N-262 Fregate  Transport aircraft
# 7               Nigeria        (2)               Il-28     Bomber aircraft
# 8        Western Sahara        (3)            BTR-60PB                 APC
# 9                   NaN        NaN                 NaN                 NaN
# 10               Angola        NaN                 NaN                 NaN
# ...

# %%
df = df[1:]

# %%
import numpy as np

# %%
df.head(20)
# Out:
#              Unnamed: 0 Unnamed: 1          Unnamed: 2          Unnamed: 3  \
# 1                   NaN        NaN                 NaN                 NaN
# 2               Albania        NaN                 NaN                 NaN
# 3       R: Burkina Faso       (12)          M-43 120mm              Mortar
# 4                   NaN        NaN                 NaN                 NaN
# 5               Algeria        NaN                 NaN                 NaN
# 6             R: Angola          4       N-262 Fregate  Transport aircraft
# 7               Nigeria        (2)               Il-28     Bomber aircraft
# 8        Western Sahara        (3)            BTR-60PB                 APC
# 9                   NaN        NaN                 NaN                 NaN
# 10               Angola        NaN                 NaN                 NaN
# 11             R: Congo          1            Noratlas  Transport aircraft
# ...

# %%
shftrs = df.iloc[:,1].isnull()
sups = ~df.iloc[:,0].isnotnull

# %%
df.loc[shftrs] = df.loc[shftrs]

# %%
df.loc[shftrs]
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3                     Year(s)  \
# 1            NaN        NaN        NaN        NaN                 NaN     NaN
# 2        Albania        NaN        NaN        NaN                 NaN     NaN
# 4            NaN        NaN        NaN        NaN                 NaN     NaN
# 5        Algeria        NaN        NaN        NaN                 NaN     NaN
# 9            NaN        NaN        NaN        NaN                 NaN     NaN
# ...          ...        ...        ...        ...                 ...     ...
# 27027        NaN        NaN        NaN        NaN                 NaN     NaN
# 27028     Zambia        NaN        NaN        NaN                 NaN     NaN
# 27030        NaN        NaN        NaN        NaN                 NaN     NaN
# 27031   Zimbabwe        NaN        NaN        NaN                 NaN     NaN
# 27034                   NaN          2   Pembroke  Light transport ac    1964
#
# ...

# %%
df.loc[shftrs].shift(-1, axis=1)
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2          Unnamed: 3       Year(s)  \
# 1            NaN        NaN        NaN                 NaN   NaN     NaN
# 2            NaN        NaN        NaN                 NaN   NaN     NaN
# 4            NaN        NaN        NaN                 NaN   NaN     NaN
# 5            NaN        NaN        NaN                 NaN   NaN     NaN
# 9            NaN        NaN        NaN                 NaN   NaN     NaN
# ...          ...        ...        ...                 ...   ...     ...
# 27027        NaN        NaN        NaN                 NaN   NaN     NaN
# 27028        NaN        NaN        NaN                 NaN   NaN     NaN
# 27030        NaN        NaN        NaN                 NaN   NaN     NaN
# 27031        NaN        NaN        NaN                 NaN   NaN     NaN
# 27034        NaN          2   Pembroke  Light transport ac  1964    1964
#
#       Unnamed: 6                                          Supplier/ Unnamed: 8
# ...

# %%
df
# Out:
#             Unnamed: 0 Unnamed: 1  Unnamed: 2          Unnamed: 3  \
# 1                  NaN        NaN         NaN                 NaN
# 2              Albania        NaN         NaN                 NaN
# 3      R: Burkina Faso       (12)  M-43 120mm              Mortar
# 4                  NaN        NaN         NaN                 NaN
# 5              Algeria        NaN         NaN                 NaN
# ...                ...        ...         ...                 ...
# 27030              NaN        NaN         NaN                 NaN
# 27031         Zimbabwe        NaN         NaN                 NaN
# 27032       R: Czechia         10   2S1 122mm  Self-propelled gun
# 27033           Zambia       (28)      Ferret                 APV
# 27034                         NaN           2            Pembroke
#
#                           Year(s) Unnamed: 6  \
# 1                     NaN     NaN        NaN
# 2                     NaN     NaN        NaN
# ...
